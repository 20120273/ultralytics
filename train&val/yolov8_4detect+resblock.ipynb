# %%
# !git clone https://github.com/20120273/ultralytics
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 26414, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 26414 (delta 6), reused 12 (delta 5), pack-reused 26400
# Receiving objects: 100% (26414/26414), 15.61 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (18536/18536), done.
# Obtaining file:///kaggle/working/ultralytics
# done
#   Checking if build backend supports build_editable ... done
# done
# done
# ...
# done
#   Created wheel for ultralytics: filename=ultralytics-8.2.18-0.editable-py3-none-any.whl size=22893 sha256=96d4adc43aba6ce41e86297fc9767662b40d609c793ba08667eba762a3abe950
#   Stored in directory: /tmp/pip-ephem-wheel-cache-53_pl41r/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# ...

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
# !yolo task=detect \
mode=train \
model=yolov8_light4detect_resblock.yaml \
data=/kaggle/input/dataset/data.yaml \
epochs=200 \
imgsz=640
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
