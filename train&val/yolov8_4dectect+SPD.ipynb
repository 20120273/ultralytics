# %%
# !git clone https://github.com/khuong253/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 21208, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 21208 (delta 11), reused 15 (delta 5), pack-reused 21182
# Receiving objects: 100% (21208/21208), 12.45 MiB | 27.95 MiB/s, done.
# Resolving deltas: 100% (14681/14681), done.

# %%
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# Obtaining file:///kaggle/working/ultralytics
# done
#   Checking if build backend supports build_editable ... done
# done
# done
# ...
# done
#   Created wheel for ultralytics: filename=ultralytics-8.2.2-0.editable-py3-none-any.whl size=22732 sha256=4588c24daa450bbebb97453240d8e1f69917d14cb88f5e9e9af016c0370c90fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lscuoyye/wheels/1b/eb/7d/853f2df0532389050170c8cd117b40e1fef8d125854a910fe6
# Successfully built ultralytics
# ...

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
# !yolo task=detect \
mode=train \
model=yolov8n.yaml \
data=/kaggle/input/trafficsigndetect-final/data.yaml\
epochs=200 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8n_4dectect_SPD.yaml \
data=/kaggle/input/trafficsigndetect-final/data.yaml\
epochs=200 \
imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
